# %% [markdown]
# # CS1010 Assignment 1
# ### Instructor:
# **Prof. Kartik Bulusu [CS & MAE]**
#
# ### Teaching Assistants:
# **Marshall Thompspon [CS], Jonathan Garcia [MAE], Matthew Dionne [CS]**
#
# ### Learning Assistants:
# **Josie Libbon [CS], Josh Rizika [CS Dept], Miles Grant [CS], Addy Irankunda [Physics], Talia Novack [CS] Fred Kamgang [CS]**

# %% [markdown]
# Put your team's names in the below cell inside the quotation marks!

# %%
#we have imported the math library for you!
#Please use 'Shift+Enter' to execute this cell
import math
import numpy as np

# %%
#Your names go here!
student1 = ''
student2 = ''
student3 = ''

print('Group member 1 is named ' + student1)
print('Group member 2 is named ' + student2)
print('Group member 3 is named ' + student3)

# %% [markdown]
# ## How to Answer Questions
# - Each question should be answered by one team member.
# - Add a comment with your name next to the quesiton that you answered .
#     - For example, If you have to define a variable called x that is equal to 5 type: `x = 5 #Student Name Here`
#
#
# - Divide the work between group members.
#     - For example, if there are 6 questions, each student does 2 questions.
#     -  If there are extra questions make sure there is an answer individually or as a group answer. We will treat it as a bonus and help you with the grade.
# - **Working together is encourgaged!** But, everyone must type the answer to their question(s).
#     - The revision history is visible to the instruction team and we can determine who executed, or modified a code.
# - Grade will be assigned to students (in a group) who followed these instructions and answered the HW questions accordingly.

# %% [markdown]
# ## Question 1.
#  Save the value of `20` to a variable called `twenty`, then print that variable.
#
#  Also save the value of `15` to a variable called `number` and print that variable.

# %%
#Student 1 - This is your first question. Type your code and comment your name!

# %% [markdown]
# ## Question 2.
# Save the string of the word `Hi` to a variable called `greeting`, and print the variable
#
# **Hint**: remember strings require quotations!

# %%
#Student 2 - This is your first question. Type your code and comment your name!

# %% [markdown]
# ## Question 3.
# Multiply the variable `twenty` by the variable `number`. Save this result as `product` and print the result

# %%
#Student 3 - This is your first question. Type your code and comment your name!

# %% [markdown]
# ## Question 4.
# Calculate the cosine ( $\cos()$ ) of the value $\pi$ and save it to a variable called `x`.
#
# **Hint**: use the math library to calculate $\pi$ and $\cos()$

# %%
#Student 1 - This is your second question. Type your code and comment your name!

# %% [markdown]
# ## Question 5.
#
# Compute the following equation using python and printing the value. And print the y value
#
# - G = 1,
# - M = 10
# - L = 2
# - r = 3
# - s = 1
#
# $y= -GM \frac{s}{r^2\sqrt{r^2 +L^2/4}}$

# %%
#Student 2 - This is your second question. Type your code and comment your name!

# %% [markdown]
# ## Question 6.
# Write a code to calculate the following and save the result to a variable named `y`:
#
# $y = \frac{400+\frac{37}{43}}{(10)(3-18)}$
#
# **Hint**: Be careful with parenthesis!

# %%
#Student 3 - This is your second question. Type your code and comment your name!

# %% [markdown]
# ## Congrats!!
#  You completed your first Python Assignment in CS 1010! Give yourself a round of applause!!

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7dc91a80-ae46-4ae1-897f-4f90a46b055c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
